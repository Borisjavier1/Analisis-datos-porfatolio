# %% [markdown]
# <center><img src ="car.png"><center>

# %% [markdown]
# <h1 style="color:#725b75; text-align: center"; >Universidad Castro Carazo</h1>
# <h4 style="color:#c1a2a0; text-align: center";>2C - 2024 Analisis de datos</h4>
# </br>
# <p style="text-align: justify; font-family: Times New Roman">El análisis de datos es la ciencia que se encarga de examinar un conjunto de datos con el propósito de sacar conclusiones sobre la información para poder tomar decisiones, o simplemente ampliar los conocimientos sobre diversos temas.</p>

# %% [markdown]
# <table>
#   <tr>
#     <th><img src ="peligro.png" width="50" height="50"></th>
#     <th>Enlace del Data Set que se va a usar en el cuatrimestre</th>
#     <th><a href="https://archive.ics.uci.edu/dataset/10/automobile">Repositorio UCI</a></th>
#   </tr>
# </table>

# %% [markdown]
# ﻿
#
# <h2 style="color: #2790b0">1. Carga y estandarizacion de los set de datos</h2>
# <ol>
# <li>Importar las librerias necesarias para trabajar</li> <li>Importar los archivos CSV (Set Datos DataFrame)</li> <li>Revision de los encabezados de los Set Datos</li>
# <li>Generar un unico DataFrame</li>
# </ol>
# <h4 Style="color: #2b4e72 "> Importando Librerias necesarias para trabajar</h4>

# %%
import numpy as np #Estructuras de datos
import pandas as pd #Marcos de datos
import matplotlib as mpl #Generar graficos
import matplotlib.pyplot as plt #Generar graficos
import seaborn as sn #Generar graficos

# %% [markdown]
# <h4 Style="color: #2b4e72 "> Importando los data set</h4>

# %%
# Esta linea es para definir los titulos de cada variables (Columnas) 
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors",
"style", "wheels", "engine", "base", "length", "width", "heingt",
"curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke", 
"compression", "horsepower", "peak", "City", "Higway", "price"]

# %%
#Esta linea de codigo permite cargar archivos que estan en carpetas
dfAuto1 = pd.read_csv("DataSet/Autos1.csv", names=cols)
dfAuto2 = pd.read_csv("DataSet/autos.csv", names=cols)
print("se cargaron los archivos")
# Out:
# se cargaron los archivos

# %%
#Se puede visualizar los primeros N observaciones del Data Frame 
dfAuto1.head (5)
#Se puede visualizar los ultimos N registros del Data Frame
#dfAutol.tail (3)
#Se puede visualizar los primeros y ultimos registros del Data Frame dfAuto2
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engineSize  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
#
#    peak city  highway  price
# ...

# %%
#Tamanios
#dfAuto1.shape
dfAuto2.shape
# Out:
# (197, 26)

# %% [markdown]
# ﻿<h4 Style="color: #2b4e72"> Revisar Encabezados de las Columnas</h4>
# <table style="width:100%">
# <tr>
# <td><img src="peligro.png" width="50" height="50"></td>
# <td>Sanas Practicas para nombrar variables</td>
# </tr>
# </table>
# <ol>
# <li>Los nombres NO deben iniciar con un numero</li>
# <li>NO se debe utilizar nombres iguales a palabras reservadas</li> <li>NO deben contener espacion en blanco</li>
# <li>Deben iniciar en minuscula</li>
# <li>Deben estar en el mismo idioma</li>
# </ol>

# %%
dfAuto1.columns #ver columnas
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
dfAuto1.rename({'Cylinders': 'cylinders'}, axis=1, inplace=True)
dfAuto2.rename({'Cylinders': 'cylinders'}, axis=1, inplace=True)
dfAuto1.rename({'City': 'city'}, axis=1, inplace=True)
dfAuto2.rename({'City': 'city'}, axis=1, inplace=True)
dfAuto1.rename({'Higway': 'highway'}, axis=1, inplace=True)
dfAuto2.rename({'Higway': 'highway'}, axis=1, inplace=True)
dfAuto1.rename({'engine-size': 'engineSize'}, axis=1, inplace=True)
dfAuto2.rename({'engine-size': 'engineSize'}, axis=1, inplace=True)

# %% [markdown]
# ﻿<h4 Style="color: #2b4e72">Unir los Data Set</h4>

# %%
unionArchivos = [dfAuto1, dfAuto2]
dfAutos = pd.concat(unionArchivos)
dfAutos.shape
# Out:
# (226, 26)

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 226 entries, 0 to 196
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    226 non-null    int64
#  1   normalized   226 non-null    object
#  2   make         226 non-null    object
#  3   fuel         226 non-null    object
#  4   aspiration   226 non-null    object
#  5   doors        226 non-null    object
#  6   style        226 non-null    object
#  7   wheels       226 non-null    object
#  8   engine       226 non-null    object
#  9   base         226 non-null    float64
#  10  length       226 non-null    float64
#  11  width        226 non-null    float64
#  12  heingt       226 non-null    float64
#  13  curb         226 non-null    int64
#  14  engineType   226 non-null    object
#  15  cylinders    226 non-null    object
#  16  engineSize   226 non-null    int64
#  17  system       226 non-null    object
# ...

# %% [markdown]
# Caracteristicas a revisar:
#
# price object deberia ser float
# peak object deberia ser int horsepower
# object deberia ser int
# stroke object deberia ser float
# bore object deberia ser float
# normalized object deberia ser int

# %%
dfAutos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  226.000000  226.000000  226.000000  226.000000  226.000000
# mean     0.902655   98.626991  173.929646   65.853982   53.728761
# std      1.271672    5.611570   11.744470    2.015475    2.365420
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  167.300000   64.200000   52.000000
# 50%      1.000000   97.250000  173.200000   65.500000   54.100000
# 75%      2.000000  101.800000  180.200000   66.500000   55.600000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engineSize  compression        city     highway
# count   226.000000  226.000000   226.000000  226.000000  226.000000
# mean   2540.597345  126.486726    10.300973   25.477876   31.044248
# std     498.165891   40.340465     4.148393    6.384143    6.767096
# min    1488.000000   61.000000     7.000000   13.000000   16.000000
# ...

# %% [markdown]
# <h2 Style = "color:  #2790b0 ">2. Manejo de valores faltantes</h2>
#
# <ol>
# <li>Identificar como se muestran los valores faltantes (NaN, ?, null, EspacioEnBlanco)</li>
# <li>Contar la cantidad de valores faltantes en cada una de las caracteristicas</li>
# <li>Imputacion simple de valores numericos</li>
# <li>Imputacion simple de valores categoricos</li>
# <li>Eliminar observaciones o registros</li>
# </ol>
#
# <h4 Style="color:#2b4e72 "> Identificar como se muestran los valores faltantes</h4>

# %%
dfAutos.replace('?', np.nan, inplace=True)

# %%
dfAutos.tail(5)
# Out:
#      symboling normalized        make    fuel aspiration doors  style wheels  \
# 192          0        NaN  volkswagen  diesel      turbo  four  sedan    fwd
# 193          0        NaN  volkswagen     gas        std  four  wagon    fwd
# 194         -2        103       volvo     gas        std  four  sedan    rwd
# 195         -1         74       volvo     gas        std  four  wagon    rwd
# 196         -2        103       volvo     gas        std  four  sedan    rwd
#
#     engine   base  ...  engineSize  system  bore  stroke compression  \
# 192  front  100.4  ...          97     idi  3.01    3.40        23.0
# 193  front  100.4  ...         109    mpfi  3.19    3.40         9.0
# 194  front  104.3  ...         141    mpfi  3.78    3.15         9.5
# 195  front  104.3  ...         141    mpfi  3.78    3.15         9.5
# 196  front  104.3  ...         141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak city highway  price
# 192         68  4500   33      38  13845
# ...

# %%
#Traer valor unico de una variable para revisar
dfAutos['peak'].unique()
# Out:
# array([4800, 4200, 4500, 5200, 5250, 5500, 5400, '5000', '5500', '5800',
#        '4250', '5400', '5100', '4800', '6000', '4750', '4650', '4200',
#        '4350', '4500', '5200', '4150', '5600', '5900', '5750', nan,
#        '5250', '4900', '4400', '6600'], dtype=object)

# %%
 dfTemp = dfAutos.isnull()
for column in dfTemp.columns.values.tolist():
    print(dfTemp[column].value_counts())
    print('')
    
dfTemp.tail(5)
# Out:
# symboling
# False    226
# Name: count, dtype: int64
#
# normalized
# False    180
# True      46
# Name: count, dtype: int64
#
# make
# False    226
# Name: count, dtype: int64
#
# fuel
# False    226
# Name: count, dtype: int64
#
# aspiration
# False    226
# Name: count, dtype: int64
#
# doors
# False    224
# True       2
# Name: count, dtype: int64
#
# style
# False    226
# Name: count, dtype: int64
#
# wheels
# False    226
# Name: count, dtype: int64
#
# engine
# False    226
# Name: count, dtype: int64
#
# base
# False    226
# Name: count, dtype: int64
#
# length
# False    226
# Name: count, dtype: int64
#
# width
# False    226
# Name: count, dtype: int64
#
# heingt
# False    226
# Name: count, dtype: int64
#
# curb
# False    226
# Name: count, dtype: int64
#
# engineType
# False    226
# Name: count, dtype: int64
#
# cylinders
# False    226
# Name: count, dtype: int64
#
# engineSize
# False    226
# Name: count, dtype: int64
#
# system
# False    226
# ...

# %%
for columna in dfTemp.columns.values.tolist():
    print(dfTemp[columna].value_counts())
    print('')
# Out:
# symboling
# False    226
# Name: count, dtype: int64
#
# normalized
# False    180
# True      46
# Name: count, dtype: int64
#
# make
# False    226
# Name: count, dtype: int64
#
# fuel
# False    226
# Name: count, dtype: int64
#
# aspiration
# False    226
# Name: count, dtype: int64
#
# doors
# False    224
# True       2
# Name: count, dtype: int64
#
# style
# False    226
# Name: count, dtype: int64
#
# wheels
# False    226
# Name: count, dtype: int64
#
# engine
# False    226
# Name: count, dtype: int64
#
# base
# False    226
# Name: count, dtype: int64
#
# length
# False    226
# Name: count, dtype: int64
#
# width
# False    226
# Name: count, dtype: int64
#
# heingt
# False    226
# Name: count, dtype: int64
#
# curb
# False    226
# Name: count, dtype: int64
#
# engineType
# False    226
# Name: count, dtype: int64
#
# cylinders
# False    226
# Name: count, dtype: int64
#
# engineSize
# False    226
# Name: count, dtype: int64
#
# system
# False    226
# ...

# %% [markdown]
# <h2 Style = "color:  #2790b0 "> Imputacion de valores numericos
#     por la media</h2>

# %%
#inputando valores faltantes
avg = dfAutos['normalized'].astype('float').mean(axis=0)
avg
# Out:
# 122.28333333333333

# %%
dfAutos['normalized'].replace(np.nan, 122, inplace=True)

# %%
avg = dfAutos['peak'].astype('float').mean(axis=0)
avg
# Out:
# 5100.892857142857

# %%
dfAutos['peak'].replace(np.nan, 5100, inplace=True)

# %%
avg = dfAutos['horsepower'].astype('float').mean(axis=0)
avg
# Out:
# 102.98214285714286

# %%
dfAutos['horsepower'].replace(np.nan, 102, inplace=True)

# %%
avg = dfAutos['bore'].astype('float').mean(axis=0)
avg
# Out:
# 3.319459459459459

# %%
dfAutos['bore'].replace(np.nan, 3.31, inplace=True)

# %%
avg = dfAutos['stroke'].astype('float').mean(axis=0)
avg
# Out:
# 3.2785135135135133

# %%
dfAutos['stroke'].replace(np.nan, 3.27, inplace=True)

# %% [markdown]
# <h2 Style = "color:  #2790b0 "> Inputacion de valores categoricos por dato mas frecuente</h2>

# %%
dfAutos['doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
dfAutos['doors'].replace(np.nan, 'four', inplace=True)

# %% [markdown]
# <h2 Style = "color:  #2790b0 "> Eliminar observaciones del dataFrame
# </h2>

# %%
dfAutos.dropna(subset=['price'], axis=0, inplace=True)
dfAutos.reset_index(drop=['price'], inplace=True)
dfAutos
# Out:
#      symboling normalized        make    fuel aspiration doors        style  \
# 0            2        134      toyota     gas        std   two      hardtop
# 1            2        134      toyota     gas        std   two    hatchback
# 2            2        134      toyota     gas        std   two      hardtop
# 3            2        134      toyota     gas        std   two    hatchback
# 4            2        134      toyota     gas        std   two  convertible
# ..         ...        ...         ...     ...        ...   ...          ...
# 217          0        122  volkswagen  diesel      turbo  four        sedan
# 218          0        122  volkswagen     gas        std  four        wagon
# 219         -2        103       volvo     gas        std  four        sedan
# 220         -1         74       volvo     gas        std  four        wagon
# 221         -2        103       volvo     gas        std  four        sedan
#
# ...

# %%
def missing_cols(df):
    total = 0
    for col in df.columns:
        missing_vals = df[col].isnull().sum()
        total += missing_vals
        if missing_vals != 0:
            print(f"{col} => {df[col].isnull().sum()}")
    if total == 0:
            print("No hay valores faltantes")

missing_cols(dfAutos)
# Out:
# No hay valores faltantes

# %% [markdown]
# <h2 Style = "color:  #2790b0 ">3. Estandarizacion de datos</h2>
# <ol>
#     <li>Formateo de Datos</li>
#     <li>Estandarización de los Datos</li>
#     <li>Binning</li>
# </ol>
# <h4 Style="color:#2b4e72 "> Formateo de los Datos</h4>

# %%
dfAutos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engineSize  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...         146    mpfi  3.62     3.5         9.3        116
#
#    peak city highway  price
# 0  4800   24      30   9639
# ...

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    222 non-null    int64
#  1   normalized   222 non-null    object
#  2   make         222 non-null    object
#  3   fuel         222 non-null    object
#  4   aspiration   222 non-null    object
#  5   doors        222 non-null    object
#  6   style        222 non-null    object
#  7   wheels       222 non-null    object
#  8   engine       222 non-null    object
#  9   base         222 non-null    float64
#  10  length       222 non-null    float64
#  11  width        222 non-null    float64
#  12  heingt       222 non-null    float64
#  13  curb         222 non-null    int64
#  14  engineType   222 non-null    object
#  15  cylinders    222 non-null    object
#  16  engineSize   222 non-null    int64
#  17  system       222 non-null    object
# ...

# %%
#Estas lineas de codigo es para convertir las variables al tipo de dato correcto.
#Esto es necesario previo a homogenizar los datos numericos.
dfAutos [['bore', 'stroke']] = dfAutos [['bore', 'stroke']].astype('float')
dfAutos [['price', 'horsepower', 'peak', 'normalized']] = dfAutos [['price', 'horsepower', 'peak', 'normalized']].astype('int')
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    222 non-null    int64
#  1   normalized   222 non-null    int32
#  2   make         222 non-null    object
#  3   fuel         222 non-null    object
#  4   aspiration   222 non-null    object
#  5   doors        222 non-null    object
#  6   style        222 non-null    object
#  7   wheels       222 non-null    object
#  8   engine       222 non-null    object
#  9   base         222 non-null    float64
#  10  length       222 non-null    float64
#  11  width        222 non-null    float64
#  12  heingt       222 non-null    float64
#  13  curb         222 non-null    int64
#  14  engineType   222 non-null    object
#  15  cylinders    222 non-null    object
#  16  engineSize   222 non-null    int64
#  17  system       222 non-null    object
# ...

# %%
#Esta linea de codigo permite conocer los valores unicos de cada variable
dfAutos['style'].unique()
# Out:
# array(['hardtop', 'hatchback', 'convertible', 'sedan', 'wagon'],
#       dtype=object)

# %%
#Esta linea se usa para remplazar valores y homogenizar los datos categoricos
dfAutos['make'].replace('alfa-romero', 'alfaRomero', inplace = True)
dfAutos['make'].replace('mercedes-benz', 'mercedes_benz', inplace = True)
dfAutos['make'].unique()
# Out:
# array(['toyota', 'volkswagen', 'volvo', 'alfaRomero', 'audi', 'bmw',
#        'chevrolet', 'dodge', 'honda', 'isuzu', 'jaguar', 'mazda',
#        'mercedes_benz', 'mercury', 'mitsubishi', 'nissan', 'peugot',
#        'plymouth', 'porsche', 'renault', 'saab', 'subaru'], dtype=object)

# %%
dfAutos['make'] = dfAutos['make'].str.upper()
dfAutos['make'].unique()
# Out:
# array(['TOYOTA', 'VOLKSWAGEN', 'VOLVO', 'ALFAROMERO', 'AUDI', 'BMW',
#        'CHEVROLET', 'DODGE', 'HONDA', 'ISUZU', 'JAGUAR', 'MAZDA',
#        'MERCEDES_BENZ', 'MERCURY', 'MITSUBISHI', 'NISSAN', 'PEUGOT',
#        'PLYMOUTH', 'PORSCHE', 'RENAULT', 'SAAB', 'SUBARU'], dtype=object)

# %%
dfAutos['make'] = dfAutos['make'].str.lower()
dfAutos['make'].unique()
# Out:
# array(['toyota', 'volkswagen', 'volvo', 'alfaromero', 'audi', 'bmw',
#        'chevrolet', 'dodge', 'honda', 'isuzu', 'jaguar', 'mazda',
#        'mercedes_benz', 'mercury', 'mitsubishi', 'nissan', 'peugot',
#        'plymouth', 'porsche', 'renault', 'saab', 'subaru'], dtype=object)

# %%
dfAutos['bore'].unique()
# Out:
# array([3.62, 3.31, 3.27, 3.01, 3.19, 3.78, 3.47, 2.68, 3.13, 3.5 , 2.91,
#        3.03, 2.97, 3.34, 3.6 , 2.92, 3.15, 3.43, 3.63, 3.54, 3.08, 3.39,
#        3.76, 3.58, 3.46, 3.8 , 3.17, 3.35, 3.59, 2.99, 3.33, 3.7 , 3.61,
#        3.94, 3.74, 2.54, 3.05, 3.24])

# %%
dfAutos['bore'] = dfAutos['bore'].round(1)
dfAutos['bore'].unique()
# Out:
# array([3.6, 3.3, 3. , 3.2, 3.8, 3.5, 2.7, 3.1, 2.9, 3.4, 3.7, 3.9, 2.5])

# %%
dfAutos['stroke'].unique()
# Out:
# array([3.5 , 3.54, 3.35, 3.4 , 3.15, 2.68, 3.47, 2.8 , 3.19, 3.39, 3.03,
#        3.11, 3.23, 3.46, 3.9 , 3.41, 3.07, 3.58, 4.17, 2.76, 3.27, 3.16,
#        3.64, 3.1 , 3.12, 3.86, 3.29, 3.52, 2.19, 3.21, 2.9 , 2.07, 2.36,
#        2.64, 3.08])

# %%
dfAutos['stroke'] = dfAutos['stroke'].round(1)
dfAutos['stroke'].unique()
# Out:
# array([3.5, 3.4, 3.2, 2.7, 2.8, 3. , 3.1, 3.9, 3.6, 4.2, 3.3, 2.2, 2.9,
#        2.1, 2.4, 2.6])

# %%
dfAutos.describe()
# Out:
#         symboling  normalized        base      length       width      heingt  \
# count  222.000000  222.000000  222.000000  222.000000  222.000000  222.000000
# mean     0.909910  122.229730   98.661261  174.064865   65.836036   53.766667
# std      1.280198   33.651614    5.648067   11.720591    1.970382    2.367974
# min     -2.000000   65.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000  101.000000   94.500000  167.350000   64.200000   52.000000
# 50%      1.000000  122.000000   97.250000  173.200000   65.500000   54.100000
# 75%      2.000000  136.250000  102.300000  180.200000   66.500000   55.675000
# max      3.000000  256.000000  120.900000  208.100000   72.000000   59.800000
#
#               curb  engineSize        bore      stroke  compression  \
# count   222.000000  222.000000  222.000000  222.000000   222.000000
# mean   2540.418919  126.450450    3.322072    3.284685    10.323514
# ...

# %% [markdown]
# <h4 Style="color:#2b4e72 "> Estandarizacion de los Datos</h4>

# %%
dfAutos.head(3)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          2         134  toyota  gas        std   two    hardtop    rwd
# 1          2         134  toyota  gas        std   two  hatchback    rwd
# 2          2         134  toyota  gas        std   two    hardtop    rwd
#
#   engine  base  ...  engineSize  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...         146    mpfi   3.6     3.5         9.3        116
# 1  front  98.4  ...         146    mpfi   3.6     3.5         9.3        116
# 2  front  98.4  ...         146    mpfi   3.6     3.5         9.3        116
#
#    peak city  highway  price
# 0  4800   24       30   9639
# 1  4800   24       30   9989
# 2  4800   24       30  11199
#
# [3 rows x 26 columns]

# %%
dfAutos['consumoCiudad_(calc)'] = 235.21/dfAutos['city']
dfAutos['consumoCiudad_(calc)'] = dfAutos['consumoCiudad_(calc)'].round(1)
 
dfAutos['consumoPista_(calc)'] = 235.21/dfAutos['highway']
dfAutos['consumoPista_(calc)'] = dfAutos['consumoPista_(calc)'].round(1)
dfAutos.head(3)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          2         134  toyota  gas        std   two    hardtop    rwd
# 1          2         134  toyota  gas        std   two  hatchback    rwd
# 2          2         134  toyota  gas        std   two    hardtop    rwd
#
#   engine  base  ...  bore  stroke  compression  horsepower  peak city  \
# 0  front  98.4  ...   3.6     3.5          9.3         116  4800   24
# 1  front  98.4  ...   3.6     3.5          9.3         116  4800   24
# 2  front  98.4  ...   3.6     3.5          9.3         116  4800   24
#
#    highway  price  consumoCiudad_(calc)  consumoPista_(calc)
# 0       30   9639                   9.8                  7.8
# 1       30   9989                   9.8                  7.8
# 2       30  11199                   9.8                  7.8
#
# [3 rows x 28 columns]

# %% [markdown]
# <h4 Style="color:#2b4e72 "> Binnig de los Datos</h4>

# %%
bins = np.linspace(min(dfAutos['consumoCiudad_(calc)']), max(dfAutos['consumoCiudad_(calc)']),4)
bins
# Out:
# array([ 4.8       ,  9.23333333, 13.66666667, 18.1       ])

# %%
categorias = ['bajoConsumo', 'consumoMedio', 'altoConsumo']
 
dfAutos['consumoCombustibleCiudad_(cat)'] = pd.cut(dfAutos['consumoCiudad_(calc)'], bins, labels=categorias, include_lowest=True)
temp = dfAutos[['consumoCiudad_(calc)', 'consumoCombustibleCiudad_(cat)']]
temp.head(5)
# Out:
#    consumoCiudad_(calc) consumoCombustibleCiudad_(cat)
# 0                   9.8                   consumoMedio
# 1                   9.8                   consumoMedio
# 2                   9.8                   consumoMedio
# 3                   9.8                   consumoMedio
# 4                   9.8                   consumoMedio

# %%
dfAutos['consumoCombustibleCiudad_(cat)'].unique()
# Out:
# ['consumoMedio', 'bajoConsumo', 'altoConsumo']
# Categories (3, object): ['bajoConsumo' < 'consumoMedio' < 'altoConsumo']

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors        style wheels  \
# 0          2         134  toyota  gas        std   two      hardtop    rwd
# 1          2         134  toyota  gas        std   two    hatchback    rwd
# 2          2         134  toyota  gas        std   two      hardtop    rwd
# 3          2         134  toyota  gas        std   two    hatchback    rwd
# 4          2         134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  stroke  compression  horsepower  peak city highway  \
# 0  front  98.4  ...     3.5          9.3         116  4800   24      30
# 1  front  98.4  ...     3.5          9.3         116  4800   24      30
# 2  front  98.4  ...     3.5          9.3         116  4800   24      30
# 3  front  98.4  ...     3.5          9.3         116  4800   24      30
# 4  front  98.4  ...     3.5          9.3         116  4800   24      30
#
#    price consumoCiudad_(calc)  consumoPista_(calc)  \
# ...

# %% [markdown]
# <h2 Style = "color:  #2790b0 ">4. Visualizacion de datos</h2>
#
# <ol>
#     <li>Cual es la cantidad de carros segun fabricante?</li>
#     <li>Cual es el porcentaje de carros segun la cantidad de puertas?</li>
#     <li>Cual es la relacion que existen el consumo de gasolina y el tamano del motor?</li>
# </ol>
#
# <h4 Style="color:#2b4e72 "> Atender preguntas</h4>

# %%
#Definir los parametros generales de los graficos.
#Nota: Elimina las lineas que encierran los graficos creados.
mpl.rcParams["axes.spines.bottom"] = True
mpl.rcParams["axes.spines.left"] = False
mpl.rcParams["axes.spines.right"] = False
mpl.rcParams["axes.spines.top"] = False

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors        style wheels  \
# 0          2         134  toyota  gas        std   two      hardtop    rwd
# 1          2         134  toyota  gas        std   two    hatchback    rwd
# 2          2         134  toyota  gas        std   two      hardtop    rwd
# 3          2         134  toyota  gas        std   two    hatchback    rwd
# 4          2         134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  stroke  compression  horsepower  peak city highway  \
# 0  front  98.4  ...     3.5          9.3         116  4800   24      30
# 1  front  98.4  ...     3.5          9.3         116  4800   24      30
# 2  front  98.4  ...     3.5          9.3         116  4800   24      30
# 3  front  98.4  ...     3.5          9.3         116  4800   24      30
# 4  front  98.4  ...     3.5          9.3         116  4800   24      30
#
#    price consumoCiudad_(calc)  consumoPista_(calc)  \
# ...

# %%
dfg = dfAutos.groupby(['make']).count()
dfg = dfg.iloc[:,:1]
dfg = dfg.sort_values('symboling', ascending = False)
dfg.head(5)
# Out:
#             symboling
# make
# toyota             46
# volkswagen         24
# nissan             18
# mazda              17
# mitsubishi         13

# %%
fig, ax = plt.subplots(1,1, figsize = (15,6.9), dpi = 100)

etiqueta = dfg.index.tolist()
counts = dfg['symboling'].tolist()
bar_colors = ['#f75e50','#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC',
              '#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC','#DCDCDC',
              '#7d7769']

ax.barh(etiqueta, counts, color=bar_colors)
#----------------------------------------------------------------------------------------------------------------------------#
#Formato del grafico.

titulo = 'Grafico 1: Inventario de Vehiculos'
plt.suptitle(titulo,
             horizontalalignment = 'left',
            x = 0.001,
            y = 0.87,
            transform = fig.transFigure,
            fontsize = 20,
            fontweight = 'bold',
            fontfamily = 'serif')

subtitulo = 'Cantidad de carros segun fabricante'
ax.set_title(subtitulo,
             ha = 'left',
            x = 0.001,
            y = 0.80,
            transform = fig.transFigure,
            fontsize = 12,
            fontweight = 'regular',
            fontfamily = 'serif')

etiqueta = 'Cantidad de vehiculos'
ax.set_xlabel(etiqueta,
             ha = 'left',
             fontsize = 10,
             fontweight = 'regular',
             fontfamily = 'serif')

ax.xaxis.set_label_coords(x=0, y= -0.06, transform=ax.transAxes)
ax.text(46.5, -0.409, "46")
plt.subplots_adjust(top=0.80)

plt.savefig('Graf1.png')

plt.show()

# %%
dfg = dfAutos.groupby(['doors']).count()
dfg = dfg.iloc[:,:1]
dfg = dfg.sort_values('symboling', ascending = False)
dfg.head(5)
# Out:
#        symboling
# doors
# four         125
# two           97

# %%
fig, ax = plt.subplots(1,1, figsize = (8,6.9), dpi = 100)

etiqueta = dfg.index.tolist()
counts = dfg['symboling'].tolist()

#Dibujar un circulo blanco.
circulo = plt.Circle((0,0), 0.7, color ='white')

ax.pie(counts,
      labels = etiqueta,
      autopct = '%1.1f%%',
      colors = ['#f75e50','#eac761'])

p = plt.gcf()
p.gca().add_artist(circulo)

#----------------------------------------------------------------------------------------------------------------------------#
#Formato del grafico.

titulo = 'Grafico 2: Inventario de Vehiculos'
plt.suptitle(titulo,
             horizontalalignment = 'left',
            x = 0.001,
            y = 0.87,
            transform = fig.transFigure,
            fontsize = 20,
            fontweight = 'bold',
            fontfamily = 'serif')

subtitulo = 'Porcentaje de Carros según la cantidad de puertas'
ax.set_title(subtitulo,
             ha = 'left',
            x = 0.001,
            y = 0.80,
            transform = fig.transFigure,
            fontsize = 12,
            fontweight = 'regular',
            fontfamily = 'serif')

plt.subplots_adjust(top=0.80)

plt.savefig('Graf2.png')

plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize = (15,6.9), dpi = 100)

n = 222
x = dfAutos['engineSize']
y = dfAutos['consumoCiudad_(calc)']
colors = np.random.rand(n)

ax.scatter(x,y,c=colors, alpha = 0.5, edgecolors = 'face')

#----------------------------------------------------------------------------------------------------------------------------#
#Formato del grafico.

titulo = 'Grafico 3: Inventario de Vehiculos'
plt.suptitle(titulo,
             horizontalalignment = 'left',
            x = 0.001,
            y = 0.87,
            transform = fig.transFigure,
            fontsize = 20,
            fontweight = 'bold',
            fontfamily = 'serif')

subtitulo = 'Relación entre el tamaño de motor y el consumo de gasolina'
ax.set_title(subtitulo,
             ha = 'left',
            x = 0.001,
            y = 0.80,
            transform = fig.transFigure,
            fontsize = 12,
            fontweight = 'regular',
            fontfamily = 'serif')

etiqueta = 'Tamaño del Motor'
ax.set_xlabel(etiqueta,
             ha = 'left',
             fontsize = 10,
             fontweight = 'regular',
             fontfamily = 'serif')

ax.xaxis.set_label_coords(x=0, y= -0.06, transform=ax.transAxes)
ax.text(46.5, -0.409, "46")
plt.subplots_adjust(top=0.80)

plt.savefig('Graf3.png')

plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize = (15,6.9), dpi = 100)

n = 222
x = dfAutos['engineSize']
y = dfAutos['consumoCiudad_(calc)']
colors = np.random.rand(n)

area = dfAutos['horsepower']

ax.scatter(x,y,c=colors, alpha = 0.5,s = area)

#----------------------------------------------------------------------------------------------------------------------------#
#Formato del grafico.

titulo = 'Grafico 3: Inventario de Vehiculos'
plt.suptitle(titulo,
             horizontalalignment = 'left',
            x = 0.001,
            y = 0.87,
            transform = fig.transFigure,
            fontsize = 20,
            fontweight = 'bold',
            fontfamily = 'serif')

subtitulo = 'Relación entre el tamaño de motor y el consumo de gasolina'
ax.set_title(subtitulo,
             ha = 'left',
            x = 0.001,
            y = 0.80,
            transform = fig.transFigure,
            fontsize = 12,
            fontweight = 'regular',
            fontfamily = 'serif')

etiqueta = 'Tamaño del Motor'
ax.set_xlabel(etiqueta,
             ha = 'left',
             fontsize = 10,
             fontweight = 'regular',
             fontfamily = 'serif')


etiqueta_y = 'Consumo de Combustible'
ax.set_ylabel(etiqueta_y,
             ha = 'left',
             fontsize = 10,
             fontweight = 'regular',
             fontfamily = 'serif')


ax.xaxis.set_label_coords(x=0, y= -0.06, transform=ax.transAxes)
ax.yaxis.set_label_coords(x=-0.03, y= 0.60, transform=ax.transAxes)

plt.subplots_adjust(top=0.78)

plt.show()
